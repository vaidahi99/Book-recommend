# %% [markdown]
# ## Installing Libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import anvil.server
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data Loading.

# %%
book = pd.read_csv('C:\\Users\\VAIDAHI\\Downloads\\archive\\books.csv')

# %% [markdown]
# ## Data Analyzing

# %%
book.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors  original_publication_year  \
# 0              Suzanne Collins                     2008.0
# 1  J.K. Rowling, Mary GrandPré                     1997.0
# 2              Stephenie Meyer                     2005.0
# 3                   Harper Lee                     1960.0
# 4          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# 0                          The Hunger Games  ...       4780653
# ...

# %%
book.dtypes
# Out:
# id                             int64
# book_id                        int64
# best_book_id                   int64
# work_id                        int64
# books_count                    int64
# isbn                          object
# isbn13                       float64
# authors                       object
# original_publication_year    float64
# original_title                object
# title                         object
# language_code                 object
# average_rating               float64
# ratings_count                  int64
# work_ratings_count             int64
# work_text_reviews_count        int64
# ratings_1                      int64
# ratings_2                      int64
# ratings_3                      int64
# ratings_4                      int64
# ratings_5                      int64
# image_url                     object
# small_image_url               object
# dtype: object

# %%
book.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 'image_url',
#        'small_image_url'],
#       dtype='object')

# %% [markdown]
# ## Dropping the columns.

# %%
book.drop(['image_url','small_image_url'],axis=1, inplace=True)

# %%
book.columns
# Out:
# Index(['id', 'book_id', 'best_book_id', 'work_id', 'books_count', 'isbn',
#        'isbn13', 'authors', 'original_publication_year', 'original_title',
#        'title', 'language_code', 'average_rating', 'ratings_count',
#        'work_ratings_count', 'work_text_reviews_count', 'ratings_1',
#        'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5'],
#       dtype='object')

# %%
book.isnull().sum()
# Out:
# id                              0
# book_id                         0
# best_book_id                    0
# work_id                         0
# books_count                     0
# isbn                          700
# isbn13                        585
# authors                         0
# original_publication_year      21
# original_title                585
# title                           0
# language_code                1084
# average_rating                  0
# ratings_count                   0
# work_ratings_count              0
# work_text_reviews_count         0
# ratings_1                       0
# ratings_2                       0
# ratings_3                       0
# ratings_4                       0
# ratings_5                       0
# dtype: int64

# %%
book['original_publication_year'].unique()
# Out:
# array([ 2008.,  1997.,  2005.,  1960.,  1925.,  2012.,  1937.,  1951.,
#         2000.,  1813.,  2003.,  2011.,  1949.,  1945.,  1947.,  2009.,
#         1999.,  1954.,  2010.,  2002.,  1998.,  2007.,  1595.,  1988.,
#         1993.,  1950.,  1996.,  2006.,  1868.,  1847.,  2001.,  1953.,
#         1974.,  1979.,  1932.,  1884.,  1952.,  2015.,  1995.,  2004.,
#         1969.,  1936.,  1985.,  1818.,  1977.,  1811.,  -720.,  1946.,
#         1859.,  1990.,  1964.,  1989.,  1958.,  1973.,  1967.,  1911.,
#         1891.,  1897.,  1963.,  1844.,  2013.,  1862.,  1961.,  1876.,
#         1962.,  1955.,  1991.,  1600.,  1965.,  1939.,  1908.,  1850.,
#         2014.,  1606.,  1860.,  1942.,  1978.,  1815.,  1877.,  1986.,
#         1866.,  1922.,  1987.,  1851.,  1982.,  1843.,  1976.,  1994.,
#         1915.,  1956.,    nan,  1980.,  1865.,  1817.,  1957.,  1926.,
#         1943.,  1938.,  1966.,  1981.,  2016.,  1992.,  1984.,  1972.,
# ...

# %% [markdown]
# As we can see that publication year column consist of many inconsistent values we will remove the unnecessary characters.

# %%
book.original_publication_year = book['original_publication_year'].replace('.',' ')

# %%
book.head(20)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
book['original_publication_year'] =book['original_publication_year'].astype('str')

# %%
book['original_publication_year'].dtypes
# Out:
# dtype('O')

# %%
book.dtypes
# Out:
# id                             int64
# book_id                        int64
# best_book_id                   int64
# work_id                        int64
# books_count                    int64
# isbn                          object
# isbn13                       float64
# authors                       object
# original_publication_year     object
# original_title                object
# title                         object
# language_code                 object
# average_rating               float64
# ratings_count                  int64
# work_ratings_count             int64
# work_text_reviews_count        int64
# ratings_1                      int64
# ratings_2                      int64
# ratings_3                      int64
# ratings_4                      int64
# ratings_5                      int64
# dtype: object

# %%
book['original_publication_year'] = book['original_publication_year'].str.replace('.',' ')

# %%
book.head(20)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
size=len('original_publication_year')

# %%
print(size)
# Out:
# 25

# %%
book.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors original_publication_year  \
# 0              Suzanne Collins                    2008 0
# 1  J.K. Rowling, Mary GrandPré                    1997 0
# 2              Stephenie Meyer                    2005 0
# 3                   Harper Lee                    1960 0
# 4          F. Scott Fitzgerald                    1925 0
#
#                              original_title  ... language_code average_rating  \
# 0                          The Hunger Games  ...           eng           4.34
# ...

# %%
book.original_publication_year = book['original_publication_year'].str.strip('0')

# %%
book.head()
# Out:
#    id  book_id  best_book_id  work_id  books_count       isbn        isbn13  \
# 0   1  2767052       2767052  2792775          272  439023483  9.780439e+12
# 1   2        3             3  4640799          491  439554934  9.780440e+12
# 2   3    41865         41865  3212258          226  316015849  9.780316e+12
# 3   4     2657          2657  3275794          487   61120081  9.780061e+12
# 4   5     4671          4671   245494         1356  743273567  9.780743e+12
#
#                        authors original_publication_year  \
# 0              Suzanne Collins                     2008
# 1  J.K. Rowling, Mary GrandPré                     1997
# 2              Stephenie Meyer                     2005
# 3                   Harper Lee                     1960
# 4          F. Scott Fitzgerald                     1925
#
#                              original_title  ... language_code average_rating  \
# 0                          The Hunger Games  ...           eng           4.34
# ...

# %%
book['isbn'].unique()
# Out:
# array(['439023483', '439554934', '316015849', ..., '039330762X',
#        '61711527', '375700455'], dtype=object)

# %%
book['isbn'].count()
# Out:
# 9300

# %%
book['isbn'] =book['isbn'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-b8a91ee05b10> in <module>
# ----> 1 book['isbn'] =book['isbn'].astype('float')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
book.loc[book['isbn']=='043965548X',].index[0]
# Out:
# 17

# %%
book.head(18)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
book.head(19)
# Out:
#     id   book_id  best_book_id   work_id  books_count        isbn  \
# 0    1   2767052       2767052   2792775          272   439023483
# 1    2         3             3   4640799          491   439554934
# 2    3     41865         41865   3212258          226   316015849
# 3    4      2657          2657   3275794          487    61120081
# 4    5      4671          4671    245494         1356   743273567
# 5    6  11870085      11870085  16827462          226   525478817
# 6    7      5907          5907   1540236          969   618260307
# 7    8      5107          5107   3036731          360   316769177
# 8    9       960           960   3338963          311  1416524797
# 9   10      1885          1885   3060926         3455   679783261
# 10  11     77203         77203   3295919          283  1594480001
# 11  12  13335037      13335037  13155899          210    62024035
# 12  13      5470          5470    153313          995   451524934
# ...

# %%
Loading the rating Dataset.
# Out:
#   File "<ipython-input-78-c1e36be16521>", line 1
#     Loading the rating Dataset.
#             ^
# SyntaxError: invalid syntax

# %%
rating=pd.read_csv('C:\\Users\\VAIDAHI\\Downloads\\archive\\ratings.csv')

# %%
rating.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
bt=pd.read_csv('C:\\Users\\VAIDAHI\\Downloads\\archive\\book_tags.csv')

# %%
bt.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags= pd.read_csv('C:\\Users\\VAIDAHI\\Downloads\\archive\\tags.csv')

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
tags.describe()
# Out:
#              tag_id
# count  34252.000000
# mean   17125.500000
# std     9887.845047
# min        0.000000
# 25%     8562.750000
# 50%    17125.500000
# 75%    25688.250000
# max    34251.000000

# %%
tags.columns
# Out:
# Index(['tag_id', 'tag_name'], dtype='object')

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34252 entries, 0 to 34251
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tag_id    34252 non-null  int64
#  1   tag_name  34252 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 535.3+ KB

# %%
We are looking different Generes.
# Out:
#   File "<ipython-input-88-d6d7eb611722>", line 1
#     We are looking different Generes.
#        ^
# SyntaxError: invalid syntax

# %%
tags['tag_name'].unique()
# Out:
# array(['-', '--1-', '--10-', ..., 'Ｍａｎｇａ', 'ＳＥＲＩＥＳ', 'ｆａｖｏｕｒｉｔｅｓ'],
#       dtype=object)

# %%
tags['tag_name'].count()
# Out:
# 34252

# %%
tags.dtypes
# Out:
# tag_id       int64
# tag_name    object
# dtype: object

# %%
tags.isnull().sum()
# Out:
# tag_id      0
# tag_name    0
# dtype: int64

# %%
tags.head(50)
# Out:
#     tag_id                     tag_name
# 0        0                            -
# 1        1                         --1-
# 2        2                        --10-
# 3        3                        --12-
# 4        4                       --122-
# 5        5                       --166-
# 6        6                        --17-
# 7        7                        --19-
# 8        8                         --2-
# 9        9                       --258-
# 10      10                         --3-
# 11      11                        --33-
# 12      12                         --4-
# 13      13                         --5-
# 14      14                        --51-
# 15      15                         --6-
# 16      16                        --62-
# 17      17                         --8-
# 18      18                        --99-
# 19      19  --available-at-raspberrys--
# 20      20                      -2001--
# 21      21                     -calif--
# ...

# %%
tags.tail()
# Out:
#        tag_id    tag_name
# 34247   34247   Ｃhildrens
# 34248   34248   Ｆａｖｏｒｉｔｅｓ
# 34249   34249       Ｍａｎｇａ
# 34250   34250      ＳＥＲＩＥＳ
# 34251   34251  ｆａｖｏｕｒｉｔｅｓ

# %%
book['authors'].unique()
# Out:
# array(['Suzanne Collins', 'J.K. Rowling, Mary GrandPré',
#        'Stephenie Meyer', ..., 'Ian Mortimer', 'Peggy Orenstein',
#        'John Keegan'], dtype=object)

# %%
book['original_publication_year'].isnull().sum()
# Out:
# 0

# %%
book[book['original_publication_year'].isna()]
# Out:
# Empty DataFrame
# Columns: [id, book_id, best_book_id, work_id, books_count, isbn, isbn13, authors, original_publication_year, original_title, title, language_code, average_rating, ratings_count, work_ratings_count, work_text_reviews_count, ratings_1, ratings_2, ratings_3, ratings_4, ratings_5]
# Index: []
#
# [0 rows x 21 columns]

# %%
book['authors'].value_counts(dropna=False)
# Out:
# Stephen King                                     60
# Nora Roberts                                     59
# Dean Koontz                                      47
# Terry Pratchett                                  42
# Agatha Christie                                  39
#                                                  ..
# H.P. Lovecraft, August Derleth, Robert Bloch      1
# Suki Kim                                          1
# Howard Zinn                                       1
# Ben Goldacre                                      1
# Alexandre Dumas, David Coward, Auguste Maquet     1
# Name: authors, Length: 4664, dtype: int64

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
genres = ["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics",
          "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction",
          "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror",
          "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal",
          "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction", 
          "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

# %%
Converting into small characters.

# %%
genres = list(map(str.lower, genres))
genres[:9]
# Out:
# ['art',
#  'biography',
#  'business',
#  'chick lit',
#  "children's",
#  'christian',
#  'classics',
#  'comics',
#  'contemporary']

# %%
In this we are looking genres which are also available in tags dataset.
# Out:
#   File "<ipython-input-102-accace74929e>", line 1
#     In this we are looking genres which are also available in tags dataset.
#        ^
# SyntaxError: invalid syntax

# %%
available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]
available_genres.tail()
# Out:
#        tag_id      tag_name
# 28384   28384  spirituality
# 28422   28422        sports
# 29076   29076      suspense
# 30358   30358      thriller
# 31155   31155        travel

# %%
available_genres_books = bt[bt.tag_id.isin(available_genres.tag_id)]

# %%
print('There are {} books that are tagged with above genres'.format(available_genres_books.shape[0]))
# Out:
# There are 60573 books that are tagged with above genres

# %%
available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values
available_genres_books.head(10)
# Out:
#      goodreads_book_id  tag_id  count         genre
# 1                    1   11305  37174       fantasy
# 5                    1   11743   9954       fiction
# 25                   1    7457    958      classics
# 38                   1   22973    673    paranormal
# 52                   1   20939    465       mystery
# 73                   1   26138    334       romance
# 83                   1    8055    289  contemporary
# 102                  2   11305   3441       fantasy
# 108                  2   11743    972       fiction
# 118                  2   22973    688    paranormal

# %%
book['original_publication_year'].unique()
# Out:
# array(['2008 ', '1997 ', '2005 ', '1960 ', '1925 ', '2012 ', '1937 ',
#        '1951 ', '2000 ', '1813 ', '2003 ', '2011 ', '1949 ', '1945 ',
#        '1947 ', '2009 ', '1999 ', '1954 ', '2010 ', '2002 ', '1998 ',
#        '2007 ', '1595 ', '1988 ', '1993 ', '1950 ', '1996 ', '2006 ',
#        '1868 ', '1847 ', '2001 ', '1953 ', '1974 ', '1979 ', '1932 ',
#        '1884 ', '1952 ', '2015 ', '1995 ', '2004 ', '1969 ', '1936 ',
#        '1985 ', '1818 ', '1977 ', '1811 ', '-720 ', '1946 ', '1859 ',
#        '1990 ', '1964 ', '1989 ', '1958 ', '1973 ', '1967 ', '1911 ',
#        '1891 ', '1897 ', '1963 ', '1844 ', '2013 ', '1862 ', '1961 ',
#        '1876 ', '1962 ', '1955 ', '1991 ', '1600 ', '1965 ', '1939 ',
#        '1908 ', '1850 ', '2014 ', '1606 ', '1860 ', '1942 ', '1978 ',
#        '1815 ', '1877 ', '1986 ', '1866 ', '1922 ', '1987 ', '1851 ',
#        '1982 ', '1843 ', '1976 ', '1994 ', '1915 ', '1956 ', 'nan',
# ...

# %%
year_count = book.groupby('original_publication_year')['title'].count()

# %%
year_count.head(10)
# Out:
# original_publication_year
# -17       1
# -1750     1
# -300      1
# -330      1
# -335      1
# -350      2
# -380      1
# -385      2
# -390      1
# -400      2
# Name: title, dtype: int64

# %%
plt.figure(figsize=(18,5))
year_count.plot();

# %%
year_count = year_count.astype(int)

# %%
year_count.dtypes
# Out:
# dtype('int32')

# %%
year_count = year_count.astype(str)

# %%
book[['title', 'original_publication_year']].sort_values('original_publication_year').head(10)
# Out:
#                                                   title  \
# 1279                                         The Aeneid
# 2075                              The Epic of Gilgamesh
# 1098                                       Tao Te Ching
# 8471                                        Metaphysics
# 9303                                            Poetics
# 3948                                           Politics
# 3929                             The Nicomachean Ethics
# 771                                        The Republic
# 6895  Five Dialogues: Euthyphro, Apology, Crito, Men...
# 3867                                      The Symposium
#
#      original_publication_year
# 1279                      -17
# 2075                    -1750
# 1098                     -300
# 8471                     -330
# 9303                     -335
# 3948                     -350
# 3929                     -350
# 771                      -380
# 6895                     -385
# 3867                     -385

# %%
book[['book_id', 'title', 'original_publication_year']].sort_values('original_publication_year').tail(10)
# Out:
#       book_id                                              title  \
# 5871  9748274          A Tale of Two Cities / Great Expectations
# 7215   809849                     Dear Zoo: A Lift-the-Flap Book
# 5609  1044141     The 8th Habit: From Effectiveness to Greatness
# 4707  9832370               BookRags Summary:  A Storm of Swords
# 9196    11318                             Trouble Is My Business
# 4247  8724779  Marked / Betrayed / Chosen / Untamed / Hunted ...
# 6428    48811                                  Nancy Drew: #1-64
# 4228       36         The Lord of the Rings: Weapons and Warfare
# 7645   197436  Ralph S. Mouse by Beverly Cleary: Teacher Guid...
# 3505   856917                         Absolute Boyfriend, Vol. 1
#
#      original_publication_year
# 5871                       nan
# 7215                       nan
# 5609                       nan
# 4707                       nan
# 9196                       nan
# 4247                       nan
# ...

# %%
book.dropna(subset=['original_publication_year'])
# Out:
#          id  book_id  best_book_id   work_id  books_count        isbn  \
# 0         1  2767052       2767052   2792775          272   439023483
# 1         2        3             3   4640799          491   439554934
# 2         3    41865         41865   3212258          226   316015849
# 3         4     2657          2657   3275794          487    61120081
# 4         5     4671          4671    245494         1356   743273567
# ...     ...      ...           ...       ...          ...         ...
# 9995   9996  7130616       7130616   7392860           19   441019455
# 9996   9997   208324        208324   1084709           19  067973371X
# 9997   9998    77431         77431   2393986           60  039330762X
# 9998   9999  8565083       8565083  13433613            7    61711527
# 9999  10000     8914          8914     11817           31   375700455
#
#             isbn13                      authors original_publication_year  \
# ...

# %%
book[['book_id', 'title', 'original_publication_year']].sort_values('original_publication_year').tail(10)
# Out:
#       book_id                                              title  \
# 5871  9748274          A Tale of Two Cities / Great Expectations
# 7215   809849                     Dear Zoo: A Lift-the-Flap Book
# 5609  1044141     The 8th Habit: From Effectiveness to Greatness
# 4707  9832370               BookRags Summary:  A Storm of Swords
# 9196    11318                             Trouble Is My Business
# 4247  8724779  Marked / Betrayed / Chosen / Untamed / Hunted ...
# 6428    48811                                  Nancy Drew: #1-64
# 4228       36         The Lord of the Rings: Weapons and Warfare
# 7645   197436  Ralph S. Mouse by Beverly Cleary: Teacher Guid...
# 3505   856917                         Absolute Boyfriend, Vol. 1
#
#      original_publication_year
# 5871                       nan
# 7215                       nan
# 5609                       nan
# 4707                       nan
# 9196                       nan
# 4247                       nan
# ...

# %%
book.sort_values('original_publication_year').tail()
# Out:
#         id  book_id  best_book_id   work_id  books_count        isbn  \
# 4247  4248  8724779       8724779  13597737            1   312530641
# 6428  6429    48811         48811     47752            4   448445867
# 4228  4229       36            36      4414           12   618391002
# 7645  7646   197436        197436   2029633            1  1561371734
# 3505  3506   856917        856917   3874446            9  1421500167
#
#             isbn13                                         authors  \
# 4247  9.780313e+12                         P.C. Cast, Kristin Cast
# 6428  9.780448e+12                                   Carolyn Keene
# 4228  9.780618e+12  Chris   Smith, Christopher Lee, Richard Taylor
# 7645  9.781561e+12                                   Gloria Levine
# 3505  9.781422e+12                                      Yuu Watase
#
#      original_publication_year                              original_title  \
# ...

# %%
book.isnull().sum()
# Out:
# id                              0
# book_id                         0
# best_book_id                    0
# work_id                         0
# books_count                     0
# isbn                          700
# isbn13                        585
# authors                         0
# original_publication_year       0
# original_title                585
# title                           0
# language_code                1084
# average_rating                  0
# ratings_count                   0
# work_ratings_count              0
# work_text_reviews_count         0
# ratings_1                       0
# ratings_2                       0
# ratings_3                       0
# ratings_4                       0
# ratings_5                       0
# dtype: int64

# %%
authors_list = book['authors'].apply(lambda x: [a for a in x.split(', ')] if ',' in x else x)
authors_list.head()
# Out:
# 0                  Suzanne Collins
# 1    [J.K. Rowling, Mary GrandPré]
# 2                  Stephenie Meyer
# 3                       Harper Lee
# 4              F. Scott Fitzgerald
# Name: authors, dtype: object

# %%
authors_list.head(6).apply(lambda x: pd.Series(x)).stack().head(6)
# Out:
# 0  0        Suzanne Collins
# 1  0           J.K. Rowling
#    1          Mary GrandPré
# 2  0        Stephenie Meyer
# 3  0             Harper Lee
# 4  0    F. Scott Fitzgerald
# dtype: object

# %%
authors_list.head(6).apply(lambda x: pd.Series(x)).stack().head(6).reset_index(level=1, drop=True)
# Out:
# 0        Suzanne Collins
# 1           J.K. Rowling
# 1          Mary GrandPré
# 2        Stephenie Meyer
# 3             Harper Lee
# 4    F. Scott Fitzgerald
# dtype: object

# %%
splitted_authors = authors_list.apply(lambda x: pd.Series(x)).stack().reset_index(level=1, drop=True)
splitted_authors.name = 'authors'
splitted_authors.head()
# Out:
# 0    Suzanne Collins
# 1       J.K. Rowling
# 1      Mary GrandPré
# 2    Stephenie Meyer
# 3         Harper Lee
# Name: authors, dtype: object

# %%
important_columns = ['title','authors','average_rating','ratings_count','work_text_reviews_count']

# %%
df_edited_authors = book[important_columns].drop('authors', axis=1).join(splitted_authors)
df_edited_authors.head()
# Out:
#                                                title  average_rating  \
# 0            The Hunger Games (The Hunger Games, #1)            4.34
# 1  Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 1  Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 2                            Twilight (Twilight, #1)            3.57
# 3                              To Kill a Mockingbird            4.25
#
#    ratings_count  work_text_reviews_count          authors
# 0        4780653                   155254  Suzanne Collins
# 1        4602479                    75867     J.K. Rowling
# 1        4602479                    75867    Mary GrandPré
# 2        3866839                    95009  Stephenie Meyer
# 3        3198671                    72586       Harper Lee

# %%
df_edited_authors.authors.value_counts()
# Out:
# James Patterson               98
# Stephen King                  97
# Nora Roberts                  65
# Dean Koontz                   64
# Terry Pratchett               50
#                               ..
# Katherine Tiernan O'Connor     1
# Edith Pattou                   1
# Charles Tomlinson              1
# Susan Massotty                 1
# Lech Jęczmyk                   1
# Name: authors, Length: 5841, dtype: int64

# %%
authors_most_with_books = df_edited_authors.authors.value_counts()
authors_most_with_books.head(15)
# Out:
# James Patterson        98
# Stephen King           97
# Nora Roberts           65
# Dean Koontz            64
# Terry Pratchett        50
# Agatha Christie        43
# J.D. Robb              41
# Neil Gaiman            41
# Meg Cabot              38
# Janet Evanovich        37
# David Baldacci         34
# John Grisham           34
# Anne Rice              33
# Laurell K. Hamilton    31
# Michael Connelly       29
# Name: authors, dtype: int64

# %%
def plot_authors_by(df, title, xlabel, n=15, ylabel='Author', y_size=7):
    plt.figure(figsize=(15,y_size))
    ax = sns.barplot(x=df.head(n).values, y=df.head(n).index)
    plt.title(title, weight='bold')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
plot_authors_by(authors_most_with_books, 'Authors with most books', 'Number of Books', 30)

# %%
def at_least_books(df, n):
    more_than_n = df_edited_authors['authors'].value_counts().values >= n
    return df['authors'].isin(df['authors'].value_counts()[more_than_n == True].index)

# %%
def at_least_ratings_count(df, n):
    return df.ratings_count >= n

# %%
at_least_books(df_edited_authors, 5).head(10)
# Out:
# 0     True
# 1     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# Name: authors, dtype: bool

# %%
df_edited_authors['authors'].value_counts().describe()
# Out:
# count    5841.000000
# mean        2.262626
# std         3.899577
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max        98.000000
# Name: authors, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df_edited_authors.authors.value_counts().values);
plt.xlabel('number of books');
plt.ylabel('count');

# %%
plt.figure(figsize=(17,2))
sns.boxplot(x=df_edited_authors.authors.value_counts(), orient='h');
plt.xlabel('number of books');

# %%
df_edited_authors['ratings_count'].describe()
# Out:
# count    1.321600e+04
# mean     5.412710e+04
# std      1.597093e+05
# min      2.716000e+03
# 25%      1.340100e+04
# 50%      2.071900e+04
# 75%      4.015675e+04
# max      4.780653e+06
# Name: ratings_count, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.hist(df_edited_authors['ratings_count']);
plt.xlabel('number of ratings');
plt.ylabel('count');

# %%
plt.figure(figsize=(17,2))
sns.boxplot(x=df_edited_authors['ratings_count'], orient='h');

# %%
c1 = at_least_books(df_edited_authors, 5)
c2 = at_least_ratings_count(df_edited_authors, 50000)

# %%
best_rating_authors = df_edited_authors[c1 & c2].groupby('authors')['average_rating'].mean().sort_values(ascending=False)
best_rating_authors.head(15)
# Out:
# authors
# Bill Watterson        4.630000
# Francine Rivers       4.540000
# Mary GrandPré         4.497143
# Sarah J. Maas         4.496667
# Clive Barker          4.440000
# Tsugumi Ohba          4.420000
# Takeshi Obata         4.420000
# Fiona Staples         4.410000
# George R.R. Martin    4.393333
# Brandon Sanderson     4.388333
# Cassandra Clare       4.366364
# Robert Kirkman        4.365000
# Bisco Hatori          4.360000
# A.A. Milne            4.350000
# Malcolm Jones III     4.340000
# Name: average_rating, dtype: float64

# %%
print('Best Rating Authors are {} of {} authors'.format(len(best_rating_authors),len(df_edited_authors.authors.unique())))
# Out:
# Best Rating Authors are 404 of 5841 authors

# %%
plot_authors_by(best_rating_authors, 'Best Rating Authors', 'Rating', 25)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
most_ratings_authors = df_edited_authors.groupby('authors')['ratings_count'].sum().sort_values(ascending=False)
most_ratings_authors.head(15)
# Out:
# authors
# J.K. Rowling           17080451
# Mary GrandPré          15205590
# Stephen King            8946016
# Suzanne Collins         8646393
# Stephenie Meyer         8549729
# J.R.R. Tolkien          5728861
# Rick Riordan            5254151
# Dan Brown               5002760
# William Shakespeare     4622465
# Cassandra Clare         4370216
# Nicholas Sparks         4302436
# John Green              4210889
# Jane Austen             4169899
# George Orwell           4047622
# C.S. Lewis              3943519
# Name: ratings_count, dtype: int64

# %%
best_rating_authors_normalized = pd.DataFrame(best_rating_authors.values, index=best_rating_authors.index, columns=['rating'])
best_rating_authors_normalized['rating'] = scaler.fit_transform(best_rating_authors_normalized)
best_rating_authors_normalized.head()
# Out:
#                    rating
# authors
# Bill Watterson   1.000000
# Francine Rivers  0.936620
# Mary GrandPré    0.906439
# Sarah J. Maas    0.906103
# Clive Barker     0.866197

# %%
authors_rating_score = df_edited_authors['authors'].apply(lambda x: best_rating_authors_normalized.loc[x].rating if x in best_rating_authors_normalized.index else 0.0)
authors_rating_score.head()
# Out:
# 0    0.718310
# 1    0.696303
# 1    0.906439
# 2    0.403756
# 3    0.000000
# Name: authors, dtype: float64

# %%
most_ratings_authors_normalized = pd.DataFrame(most_ratings_authors.values, index=most_ratings_authors.index, columns=['total_rating'])
most_ratings_authors_normalized['total_rating'] = scaler.fit_transform(most_ratings_authors_normalized)
most_ratings_authors_normalized.head()
# Out:
#                  total_rating
# authors
# J.K. Rowling         1.000000
# Mary GrandPré        0.890216
# Stephen King         0.523682
# Suzanne Collins      0.506137
# Stephenie Meyer      0.500477

# %%
most_ratings_authors = df_edited_authors.groupby('authors')['ratings_count'].sum().sort_values(ascending=False)
most_ratings_authors.head(15)
# Out:
# authors
# J.K. Rowling           17080451
# Mary GrandPré          15205590
# Stephen King            8946016
# Suzanne Collins         8646393
# Stephenie Meyer         8549729
# J.R.R. Tolkien          5728861
# Rick Riordan            5254151
# Dan Brown               5002760
# William Shakespeare     4622465
# Cassandra Clare         4370216
# Nicholas Sparks         4302436
# John Green              4210889
# Jane Austen             4169899
# George Orwell           4047622
# C.S. Lewis              3943519
# Name: ratings_count, dtype: int64

# %%
authors_ratings_count_score = df_edited_authors['authors'].apply(lambda x: most_ratings_authors_normalized.loc[x].total_rating)
authors_ratings_count_score.head()
# Out:
# 0    0.506137
# 1    1.000000
# 1    0.890216
# 2    0.500477
# 3    0.195261
# Name: authors, dtype: float64

# %%
df_edited_authors['author_score'] = 0.5 * authors_rating_score + 0.5 * authors_ratings_count_score
df_edited_authors['author_score'].head()
# Out:
# 0    0.612224
# 1    0.848151
# 1    0.898327
# 2    0.452116
# 3    0.097631
# Name: author_score, dtype: float64

# %%
best_authors = df_edited_authors.groupby('authors')['author_score'].mean().sort_values(ascending=False)
best_authors.head(15)
# Out:
# authors
# Mary GrandPré         0.898327
# J.K. Rowling          0.848151
# Suzanne Collins       0.612224
# J.R.R. Tolkien        0.553017
# Cassandra Clare       0.535041
# Rick Riordan          0.532272
# Stephen King          0.525440
# George R.R. Martin    0.517450
# Bill Watterson        0.512536
# Sarah J. Maas         0.487520
# Francine Rivers       0.480846
# Brandon Sanderson     0.460514
# Shel Silverstein      0.459600
# Richelle Mead         0.455519
# Stephenie Meyer       0.452116
# Name: author_score, dtype: float64

# %%
plot_authors_by(best_authors, 'Best Authors', 'Score', 30)

# %%
print('Number of users is {}'.format(len(rating.user_id.unique())))
# Out:
# Number of users is 53424

# %%
rating[rating.duplicated()==True]
# Out:
#         book_id  user_id  rating
# 1171         12    40251       4
# 2474         25    32635       5
# 2959         30    31760       4
# 3020         31     8669       5
# 3334         34    26097       1
# ...         ...      ...     ...
# 979373     9975     3133       3
# 980520     9988      907       4
# 981044     9993    33994       4
# 981257     9995    28898       2
# 981369     9996    48576       5
#
# [1644 rows x 3 columns]

# %%
rating.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
rating[rating.duplicated(keep=False)==True].head(6)
# Out:
#       book_id  user_id  rating
# 1170       12    40251       4
# 1171       12    40251       4
# 2473       25    32635       5
# 2474       25    32635       5
# 2958       30    31760       4
# 2959       30    31760       4

# %%
rating_rmv_duplicates = rating.drop_duplicates()
rating_rmv_duplicates.shape
# Out:
# (980112, 3)

# %%
rating_sample = rating_rmv_duplicates.sample(frac=0.2)
rating_sample.shape
# Out:
# (196022, 3)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='rating', data=rating_sample);

# %%
rating_per_user = rating_sample.groupby('user_id')['user_id'].count()
rating_per_user
# Out:
# user_id
# 2        1
# 4        2
# 6        1
# 7        7
# 9        1
#         ..
# 53419    3
# 53420    2
# 53421    3
# 53422    4
# 53424    6
# Name: user_id, Length: 40304, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.hist(rating_per_user ,bins='auto');
plt.grid(axis='y', alpha=0.75)
plt.xlabel('number of ratings per user')
plt.ylabel('count');

# %%
mean_rating_per_user = rating_sample.groupby('user_id')['rating'].mean()
mean_rating_per_user
# Out:
# user_id
# 2        4.000000
# 4        5.000000
# 6        5.000000
# 7        4.000000
# 9        2.000000
#            ...
# 53419    3.666667
# 53420    3.500000
# 53421    5.000000
# 53422    4.500000
# 53424    4.333333
# Name: rating, Length: 40304, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.hist(mean_rating_per_user, bins='auto');
plt.grid(axis='y', alpha=0.75)
plt.xlabel('mean user rating')
plt.ylabel('count');

# %%
rating_per_book = rating_sample.groupby('book_id')['book_id'].count()
rating_per_book
# Out:
# book_id
# 1        29
# 2        23
# 3        21
# 4        22
# 5        17
#          ..
# 9996     19
# 9997     12
# 9998     13
# 9999     24
# 10000    20
# Name: book_id, Length: 10000, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.hist(rating_per_book ,bins='auto');
plt.grid(axis='y', alpha=0.75)
plt.xlabel('number of ratings per book')
plt.ylabel('count');

# %%
mean_rating_per_book = rating_sample.groupby('book_id')['rating'].mean()
mean_rating_per_book
# Out:
# book_id
# 1        4.172414
# 2        4.086957
# 3        2.952381
# 4        4.681818
# 5        4.117647
#            ...
# 9996     4.105263
# 9997     4.250000
# 9998     4.461538
# 9999     3.791667
# 10000    3.900000
# Name: rating, Length: 10000, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.hist(mean_rating_per_book, bins='auto');
plt.grid(axis='y', alpha=0.75)
plt.xlabel('mean book rating')
plt.ylabel('count');

# %%
available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]

# %%
print('Number of available tags is {} out of the {} tags in genres list'.format(available_genres.shape[0], len(genres)))
# Out:
# Number of available tags is 31 out of the 40 tags in genres list

# %%
available_books_with_genres = bt[bt.tag_id.isin(available_genres.tag_id)]
available_books_with_genres.shape
# Out:
# (60573, 3)

# %%
tag_counts = pd.DataFrame(available_books_with_genres.groupby('tag_id')['count'].sum())
tag_counts.head()
# Out:
#           count
# tag_id
# 2938      30262
# 4605     172444
# 5951      73249
# 7077      53864
# 7457    1756920

# %%
tag_counts.set_index(available_genres.tag_name, inplace=True)
tag_counts.head()
# Out:
#              count
# tag_name
# art          30262
# biography   172444
# business     73249
# christian    53864
# classics   1756920

# %%
tag_counts.sort_values('count', ascending=False, inplace=True)
tag_counts.head()
# Out:
#             count
# tag_name
# fiction   3688819
# fantasy   3548157
# classics  1756920
# romance   1231926
# mystery    872282

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='count', y=tag_counts.index, data=tag_counts, orient='h');

# %%
cols = ['books_count','original_publication_year','average_rating','ratings_count','work_ratings_count','work_text_reviews_count']

# %%
corr = book[cols].corr()
corr
# Out:
#                          books_count  average_rating  ratings_count  \
# books_count                 1.000000       -0.069888       0.324235
# average_rating             -0.069888        1.000000       0.044990
# ratings_count               0.324235        0.044990       1.000000
# work_ratings_count          0.333664        0.045042       0.995068
# work_text_reviews_count     0.198698        0.007481       0.779635
#
#                          work_ratings_count  work_text_reviews_count
# books_count                        0.333664                 0.198698
# average_rating                     0.045042                 0.007481
# ratings_count                      0.995068                 0.779635
# work_ratings_count                 1.000000                 0.807009
# work_text_reviews_count            0.807009                 1.000000

# %%
plt.figure(figsize=(13,8))
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, cmap = 'coolwarm', annot=True);

# %%
mask = np.zeros(corr.shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True

plt.figure(figsize=(13,8))
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, cmap = 'coolwarm', annot = True, mask = mask);

# %%
jp = sns.jointplot(x='ratings_count', y='average_rating', kind='reg', line_kws={'color':'cyan'}, data=book)
jp.annotate(stats.pearsonr, fontsize=12);

# %%
jp = sns.jointplot(x='books_count', y='average_rating', kind='reg', line_kws={'color':'cyan'}, data=book)
jp.annotate(stats.pearsonr, fontsize=12);

# %%
rating.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
jp = sns.jointplot(x=rating.groupby('user_id')['user_id'].count(),
                   y=rating.groupby('user_id')['rating'].mean(),
                   kind='reg', line_kws={'color':'cyan'})
jp.annotate(stats.pearsonr, fontsize=12);
plt.xlabel('number_of_rated_books');
plt.ylabel('mean_rating');

# %%
subtitle = 'harry potter' #we are finding same series.
book[book.title.str.lower().str.find(subtitle) > -1][['title']].values
# Out:
# array([["Harry Potter and the Sorcerer's Stone (Harry Potter, #1)"],
#        ['Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)'],
#        ['Harry Potter and the Order of the Phoenix (Harry Potter, #5)'],
#        ['Harry Potter and the Chamber of Secrets (Harry Potter, #2)'],
#        ['Harry Potter and the Goblet of Fire (Harry Potter, #4)'],
#        ['Harry Potter and the Deathly Hallows (Harry Potter, #7)'],
#        ['Harry Potter and the Half-Blood Prince (Harry Potter, #6)'],
#        ['Harry Potter and the Cursed Child - Parts One and Two (Harry Potter, #8)'],
#        ['Harry Potter Boxset (Harry Potter, #1-7)'],
#        ['Harry Potter: Film Wizardry'],
#        ['The Harry Potter Collection 1-4 (Harry Potter, #1-4)'],
#        ['Harry Potter and the Chamber of Secrets: Sheet Music for Flute with C.D'],
#        ['Harry Potter Boxed Set, Books 1-5 (Harry Potter, #1-5)'],
#        ['Harry Potter Page to Screen: The Complete Filmmaking Journey'],
# ...

# %%
book_series = book[book.title.str.contains('\(.*[,:]') == True][['title', 'average_rating']]

# %%
print('There are {} books that are in series'.format(book_series.shape[0]))
# Out:
# There are 4171 books that are in series

# %%
book_series.head()
# Out:
#                                                 title  average_rating
# 0             The Hunger Games (The Hunger Games, #1)            4.34
# 1   Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 2                             Twilight (Twilight, #1)            3.57
# 8               Angels & Demons  (Robert Langdon, #1)            3.85
# 11                          Divergent (Divergent, #1)            4.24

# %%
series = book_series.copy()
series['title'] = series['title'].str.findall('\(.*[,:]').apply(lambda x: x.pop()[1:-1])

# %%
series.head()
# Out:
#                title  average_rating
# 0   The Hunger Games            4.34
# 1       Harry Potter            4.44
# 2           Twilight            3.57
# 8     Robert Langdon            3.85
# 11         Divergent            4.24

# %%
jp = sns.jointplot(x=series.groupby('title')['title'].count(),
                   y=series.groupby('title')['average_rating'].mean(),
                   kind='reg', line_kws={'color':'cyan'})
jp.annotate(stats.pearsonr, fontsize=12);
plt.xlabel('number_of_volumes_in_series');
plt.ylabel('mean_rating');

# %%
title_length = book[['title', 'average_rating']]
title_length['length'] = title_length['title'].str.findall('\s').apply(lambda x: len(x)+1)

# %%
title_length.head()
# Out:
#                                                title  average_rating  length
# 0            The Hunger Games (The Hunger Games, #1)            4.34       7
# 1  Harry Potter and the Sorcerer's Stone (Harry P...            4.44       9
# 2                            Twilight (Twilight, #1)            3.57       3
# 3                              To Kill a Mockingbird            4.25       4
# 4                                   The Great Gatsby            3.89       3

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='length', y='average_rating', data=title_length);
plt.xlabel('title_length');
plt.grid()

# %%
has_subtitle = book[['title', 'average_rating']]
has_subtitle['has_subtitle'] = title_length['title'].str.contains(':', regex=False)

# %%
has_subtitle.head()
# Out:
#                                                title  average_rating  \
# 0            The Hunger Games (The Hunger Games, #1)            4.34
# 1  Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 2                            Twilight (Twilight, #1)            3.57
# 3                              To Kill a Mockingbird            4.25
# 4                                   The Great Gatsby            3.89
#
#    has_subtitle
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False

# %%
plt.figure(figsize=(6,8))
sns.boxplot(x='has_subtitle', y='average_rating', data=has_subtitle);
plt.grid()

# %%
book.head().transpose()
# Out:
#                                                                  0  \
# id                                                               1
# book_id                                                    2767052
# best_book_id                                               2767052
# work_id                                                    2792775
# books_count                                                    272
# isbn                                                     439023483
# isbn13                                                 9.78044e+12
# authors                                            Suzanne Collins
# original_publication_year                                    2008
# original_title                                    The Hunger Games
# title                      The Hunger Games (The Hunger Games, #1)
# language_code                                                  eng
# average_rating                                                4.34
# ...

# %%
rating.head()
# Out:
#    book_id  user_id  rating
# 0        1      314       5
# 1        1      439       3
# 2        1      588       5
# 3        1     1169       4
# 4        1     1185       4

# %%
bt.head()
# Out:
#    goodreads_book_id  tag_id   count
# 0                  1   30574  167697
# 1                  1   11305   37174
# 2                  1   11557   34173
# 3                  1    8717   12986
# 4                  1   33114   12716

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
available_genres = tags.loc[tags.tag_name.str.lower().isin(genres)]

# %%
available_genres.head()
# Out:
#       tag_id   tag_name
# 2938    2938        art
# 4605    4605  biography
# 5951    5951   business
# 7077    7077  christian
# 7457    7457   classics

# %%
available_genres_books = bt[bt.tag_id.isin(available_genres.tag_id)]

# %%
print('There are {} books that are tagged with above genres'.format(available_genres_books.shape[0]))
# Out:
# There are 60573 books that are tagged with above genres

# %%
available_genres_books.head()
# Out:
#     goodreads_book_id  tag_id  count
# 1                   1   11305  37174
# 5                   1   11743   9954
# 25                  1    7457    958
# 38                  1   22973    673
# 52                  1   20939    465

# %%
available_genres_books['genre'] = available_genres.tag_name.loc[available_genres_books.tag_id].values
available_genres_books.head()
# Out:
#     goodreads_book_id  tag_id  count       genre
# 1                   1   11305  37174     fantasy
# 5                   1   11743   9954     fiction
# 25                  1    7457    958    classics
# 38                  1   22973    673  paranormal
# 52                  1   20939    465     mystery

# %%
def build_chart(genre, percentile=0.85):
    df = available_genres_books[available_genres_books['genre'] == genre.lower()]
    qualified = book.set_index('book_id').loc[df.goodreads_book_id]

    v = qualified['ratings_count']
    m = qualified['ratings_count'].quantile(percentile)
    R = qualified['average_rating']
    C = qualified['average_rating'].mean()
    qualified['weighted_rating'] = (R*v + C*m) / (v + m)

    qualified.sort_values('weighted_rating', ascending=False, inplace=True)
    return qualified

# %%
df = available_genres_books[available_genres_books['genre'] == genre.lower()]
qualified = book.set_index('book_id').loc[df.goodreads_book_id]
qualified.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-207-e81f8aa2caea> in <module>
# ----> 1 df = available_genres_books[available_genres_books['genre'] == genre.lower()]
#       2 qualified = book.set_index('book_id').loc[df.goodreads_book_id]
#       3 qualified.head()
#
# NameError: name 'genre' is not defined

# %%
cols = ['title','authors','original_publication_year','average_rating','ratings_count','work_text_reviews_count','weighted_rating']

# %%
genre = 'Fantasy'
build_chart(genre)[cols].head(15)
# Out:
#                                                       title  \
# book_id
# 136251    Harry Potter and the Deathly Hallows (Harry Po...
# 862041             Harry Potter Boxset (Harry Potter, #1-7)
# 1         Harry Potter and the Half-Blood Prince (Harry ...
# 5         Harry Potter and the Prisoner of Azkaban (Harr...
# 6         Harry Potter and the Goblet of Fire (Harry Pot...
# 62291        A Storm of Swords (A Song of Ice and Fire, #3)
# 186074    The Name of the Wind (The Kingkiller Chronicle...
# 1215032   The Wise Man's Fear (The Kingkiller Chronicle,...
# 17927395  A Court of Mist and Fury (A Court of Thorns an...
# 18512     The Return of the King (The Lord of the Rings,...
# 2         Harry Potter and the Order of the Phoenix (Har...
# 7235533       The Way of Kings (The Stormlight Archive, #1)
# 3         Harry Potter and the Sorcerer's Stone (Harry P...
# 4502507   The Last Olympian (Percy Jackson and the Olymp...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

# %%
book['authors'] = book['authors'].apply(lambda x: [str.lower(i.replace(" ", "")) for i in x.split(', ')])

# %%
def get_genres(x):
    t = bt[bt.goodreads_book_id==x]
    return [i.lower().replace(" ", "") for i in tags.tag_name.loc[t.tag_id].values]

# %%
book['genres'] = book.book_id.apply(get_genres)

# %%
book['soup'] = book.apply(lambda x: ' '.join([x['title']] + x['authors'] + x['genres']), axis=1)

# %%
book.soup.head(20)
# Out:
# 0     The Hunger Games (The Hunger Games, #1) suzann...
# 1     Harry Potter and the Sorcerer's Stone (Harry P...
# 2     Twilight (Twilight, #1) stepheniemeyer young-a...
# 3     To Kill a Mockingbird harperlee classics favor...
# 4     The Great Gatsby f.scottfitzgerald classics fa...
# 5     The Fault in Our Stars johngreen favorites to-...
# 6     The Hobbit j.r.r.tolkien fantasy favorites cla...
# 7     The Catcher in the Rye j.d.salinger classics f...
# 8     Angels & Demons  (Robert Langdon, #1) danbrown...
# 9     Pride and Prejudice janeausten classics favori...
# 10    The Kite Runner khaledhosseini favorites ficti...
# 11    Divergent (Divergent, #1) veronicaroth favorit...
# 12    1984 georgeorwell erichfromm celâlüster fictio...
# 13    Animal Farm georgeorwell classics fiction favo...
# 14    The Diary of a Young Girl annefrank eleanorroo...
# 15    The Girl with the Dragon Tattoo (Millennium, #...
# 16    Catching Fire (The Hunger Games, #2) suzanneco...
# ...

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
count_matrix = count.fit_transform(book['soup'])

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
indices = pd.Series(book.index, index=book['title'])
titles = book['title']

# %%
def get_recommendations(title, n=10):
    idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    book_indices = [i[0] for i in sim_scores]
    return list(titles.iloc[book_indices].values)[:n]

# %%
get_recommendations('Mockingjay (The Hunger Games, #3)')
# Out:
# ['The Hunger Games (The Hunger Games, #1)',
#  'Catching Fire (The Hunger Games, #2)',
#  'Divergent (Divergent, #1)',
#  'Insurgent (Divergent, #2)',
#  'The Hunger Games Trilogy Boxset (The Hunger Games, #1-3)',
#  'The Ask and the Answer (Chaos Walking, #2)',
#  'Legend (Legend, #1)',
#  'Monsters of Men (Chaos Walking, #3)',
#  'Specials (Uglies, #3)',
#  'Matched (Matched, #1)']

# %%
def get_name_from_partial(title):
    return list(book.title[book.title.str.lower().str.contains(title) == True].values)

# %%
title = "fiction"
l = get_name_from_partial(title)
list(enumerate(l))
# Out:
# [(0, 'Smoke and Mirrors: Short Fiction and Illusions'),
#  (1, 'Fragile Things: Short Fictions and Wonders'),
#  (2, 'Trigger Warning: Short Fictions and Disturbances'),
#  (3,
#   "You Are Not So Smart: Why You Have Too Many Friends on Facebook, Why Your Memory Is Mostly Fiction, and 46 Other Ways You're Deluding Yourself"),
#  (4, 'The Red Badge of Courage and Selected Short Fiction  '),
#  (5, 'Stranger than Fiction'),
#  (6, 'Collected Fictions'),
#  (7, 'Heart of Darkness and Selected Short Fiction'),
#  (8, 'On Writing Well: The Classic Guide to Writing Nonfiction'),
#  (9, 'Ethan Frome and Other Short Fiction')]

# %%
get_recommendations(l[5])
# Out:
# ['Downtown Owl',
#  'Then We Came to the End',
#  'Little Children',
#  'Diary',
#  'The Hour I First Believed',
#  'Tell-All',
#  'The Tortilla Curtain',
#  'Choke',
#  'Wonder Boys',
#  'Rant']
